# %%
import numpy as np
import pandas as pd
import zipfile
import pretty_midi
from zipfile import ZipFile
import sys

import matplotlib.pyplot as plt
import librosa

sys.path.append("./code")
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from utils import process_maestro_data

# %%
tool = process_maestro_data(data_file = "maestro-v3.0.0.zip")

# %%
tool.read_midi_file(1)

# %%
tool.plot_piano_roll(start_pitch=56, end_pitch=70, savefig = True)
